# %%
from math import sin, cos, tan, radians
from sympy import*
from numpy import*
x,y,z=symbols('x,y,z')
from matplotlib.pyplot import*
import matplotlib.animation as animation
g=9.8
def Max_Height(u,theta):
    Hmax=(u*sin(radians(theta)))**2/(2*g)
    return Hmax
    return f"Maximum Height of the Projectile is {Hmax} meters"
def Time_of_flight(u,theta):
    T=(2*u*sin(radians(theta)))/g
    return f"Time of flight of the Projectile is {round(T,4)} seconds"
def Horizontal_range(u,theta):
    R=(u**2*sin(radians(2*theta))/g)
    return R

def Equation_of_path(u,theta):
    func=(x*tan(radians(theta)))-((g*x**2)/(2*u**2*cos(radians(theta))**2))   
    X_co= Horizontal_range(u,theta)
    X=linspace(0,X_co,200)
    Y= (X*tan(radians(theta)))-((g*X**2)/(2*u**2*cos(radians(theta))**2))
    plot(X,Y)
    # def anim():

    #     x_p = linspace(0,X_co,1000)
    #     y_p = (x_p*tan(radians(theta)))-((g*x_p**2)/(2*u**2*cos(radians(theta))**2))  

    #     fig, ax = subplots()
    #     ax.set_xlim([0,X_co])
    #     ax.set_ylim([0,Max_Height(u,theta)])
    #     line, = ax.plot(   [],[], lw=2,  color='g')
    #     sctr  = ax.scatter([],[], s=100, color='r')

    #     def update(i):
    #         line.set_ydata(y_p[:i+1])  # update
    #         line.set_xdata(x_p[:i+1])
    #         sctr.set_offsets((x_p[i],y_p[i]))
    #         return line,sctr
    #     ani = animation.FuncAnimation(fig, update, 1000, interval=5, blit=True)
    #     #ani.save('plotanimation.mp4')
    #     grid()
    #     show()
    grid()
    show()
    #anim()
    
    return f"Equation of path of projectile motion is {func}\n{Max_Height(u,theta)} and its range is\n{X_co} meters"
def position(u,theta):
    time=abs(float(input(f"enter a time lower than {Time_of_flight(u,theta)}")))
    x_cordi=(u*cos(radians(theta)))*time
    y_cordi=((u*sin(radians(theta)))*time)-(0.5*g*time**2)
    X_co= Horizontal_range(u,theta)
    X=linspace(0,X_co,100)
    Y= (X*tan(radians(theta)))-((g*X**2)/(2*u**2*cos(radians(theta))**2))
    plot(X,Y, color='teal')
    scatter([x_cordi],[y_cordi], color='purple', zorder=5)
    grid()
    show()
    return f"X coordinate = {(x_cordi)}, & Y coordinate= {y_cordi}"
def wall(u,theta,Wal_height,wal_distance):
    y_cordi=(wal_distance*tan(radians(theta)))-((g*wal_distance**2)/(2*u**2*cos(radians(theta))**2))
    if y_cordi<=Wal_height:
        return f"will hit the wall"
    else:
        return f"won' hit the wall"
# def anim():

#     x_p = linspace(0,Horizontal_range(u,theta),1000)
#     y_p = (x_p*tan(radians(theta)))-((g*x_p**2)/(2*u**2*cos(radians(theta))**2))  

#     fig, ax = subplots()
#     ax.set_xlim([0,2.*Horizontal_range(u,theta)])
#     ax.set_ylim([y])
#     line, = ax.plot(   [],[], lw=2,  color='g')
#     sctr  = ax.scatter([],[], s=100, color='r')

#     def update(i):
#         line.set_ydata(y_p[:i+1])  # update
#         line.set_xdata(x_p[:i+1])
#         sctr.set_offsets((x_p[i],y_p[i]))
#         return line,sctr

#     ani = animation.FuncAnimation(fig, update, 1000, interval=5, blit=True)
#     show()
#print(wall(20,70,10,20))
# print(Time_of_flight(70,35))
print(Equation_of_path(35,70))
# Out:
# <div id='179f8600-2131-4d60-8f99-b8a4d295ef5b'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 89
#      67         return f"won' hit the wall"
#      68 # def anim():
#      69
#      70 #     x_p = linspace(0,Horizontal_range(u,theta),1000)
#    (...)
#      87 #print(wall(20,70,10,20))
#      88 # print(Time_of_flight(70,35))
# ---> 89 print(Equation_of_path(35,70))
#
# Cell In[23], line 47, in Equation_of_path(u, theta)
#      45 grid()
#      46 show()
# ---> 47 anim()
#      49 return f"Equation of path of projectile motion is {func}\n{Max_Height(u,theta)} and its range is\n{X_co} meters"
#
# NameError: name 'anim' is not defined

# %% [markdown]
# Find The Maximum Height of a Projectile

# %%
u=float(input('Enter velocity '))
theta=float(input('Enter angle'))
print(Max_Height(u,theta))
# Out:
# Maximum Height of the Projectile is 82.24748208429138 meters

# %% [markdown]
# Find The Time of flight of a Projectile

# %%
u=float(input('Enter velocity '))
theta=float(input('Enter angle'))
print(Time_of_flight(u,theta))
# Out:
# Time of flight of the Projectile is 8.1939 seconds

# %% [markdown]
# The Horizontal range of a projectile

# %%
u=float(input('Enter velocity '))
theta=float(input('Enter angle'))
print(f"The Horizontal range of the projectile is {Horizontal_range(u,theta)}")
# Out:
# The Horizontal range of the projectile is 469.84631039295414

# %% [markdown]
# Equation of path of projectile motion and it's visual representation

# %%
u=float(input('Enter velocity '))
theta=float(input('Enter angle'))
print(Equation_of_path(u,theta))
# Out:
# Equation of path of projectile motion is -0.0014902905965657*x**2 + 0.70020753820971*x
# Maximum Height of the Projectile is 82.24748208429138 meters and its range is
# 469.84631039295414 meters

# %% [markdown]
# Postion of X and Y cordinates at a given time

# %%
u=float(input('Enter velocity '))
theta=float(input('Enter angle'))
print(position(u,theta))
# Out:
# X coordinate = 458.7251448018354, & Y coordinate= 7.60280435658575

# %% [markdown]
# Will a projectile hit an object of a certain height at a certain distance?

# %%
u=float(input('Enter velocity '))
theta=float(input('Enter angle'))
Wal_height=float(input("Enter the height of the wall "))
wal_distance=float(input('How far away is the wall from the throwing point?'))
print(wall(u,theta,Wal_height,wal_distance))
# Out:
# will hit the wall
